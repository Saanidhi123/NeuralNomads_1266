# %%
# !pip install ultralytics transformers torch torchvision fastapi uvicorn python-multipart pyngrok scikit-image reportlab opencv-python-headless pillow -q


from ultralytics import YOLO
from transformers import pipeline
import cv2, numpy as np, skimage, reportlab
print(" All dependencies installed successfully")

import os
os.makedirs("models", exist_ok=True)
os.makedirs("utils", exist_ok=True)
os.makedirs("uploads", exist_ok=True)
os.makedirs("outputs", exist_ok=True)
print("Folders created")


print("Downloading YOLOv11 weights...")
model = YOLO("yolo11n-seg.pt")
print(" YOLO downloaded")

print("Downloading Depth Anything V2 ")
depth_pipe = pipeline("depth-estimation", model="depth-anything/Depth-Anything-V2-Small-hf")
print("Depth model downloaded")

print("\n model_setup complete! Switch to sever.ipynb now.")
# Out:
#  All dependencies installed successfully
# Folders created
# ...
#  YOLO downloaded
# ...
# Loading weights:   0%|          | 0/287 [00:00<?, ?it/s]
# Depth model downloaded
#
#  model_setup complete! Switch to sever.ipynb now.
